# %% [markdown]
# ## Neural Network Assignment: Image Classification on MNIST
# In this assignment, you will design and implement first a multi-layer perceptron model and then a convolutional network model in Pytorch. We will use the CIFAR-10 image dataset. Please complete the rest of the notebook by doing the following tasks.
#
# - Build your network (A MLP model and a CONVNET model). There are some requirements on the network structure, please check the corresponding code sections.
# - Train your network.
# - Describe your training procedure. Plot the following:
#     1. Training and validation loss vs. training iterations.
#     2. Training and validation accuracy vs. training iterations.
# - Report a final test result on 10000 separate testing examples.
# - Give detailed explanation of your code
#
# You can follow the skeleton code in the notebook to proceed. Look for the ##TODO## mark, that's where you should write your code.
#
# Check Pytorch documentation for reference: https://pytorch.org/tutorials/

# %% [markdown]
# ## 1.1 Download data
# From this website: https://www.cs.toronto.edu/~kriz/cifar.html
# Download the CIFAR-10 python version, which is 163 MB.
# Extract the file you downloaded, you should be able to see a folder named cifar-10-batches-py. The data files are inside. ('data_batch_1', 'data_batch_2', etc..). To make things easier put these data files in a new folder called 'cifar-10-data'. The folder 'cifar-10-data' should be in the same directory as your jupyter notebook. Now we load the data into memory.
#
# # TODO you should download data

# %% [markdown]
# ## 1.2 Loading Data: you should read the website's data description and have a better understanding of the data (quote):
# Loaded in this way, each of the batch files contains a dictionary with the following elements:
# data -- a 10000x3072 numpy array of uint8s. Each row of the array stores a 32x32 colour image. The first 1024 entries contain the red channel values, the next 1024 the green, and the final 1024 the blue. The image is stored in row-major order, so that the first 32 entries of the array are the red channel values of the first row of the image.
# labels -- a list of 10000 numbers in the range 0-9. The number at index i indicates the label of the ith image in the array data.
#
# The dataset contains another file, called batches.meta. It too contains a Python dictionary object. It has the following entries:
# label_names -- a 10-element list which gives meaningful names to the numeric labels in the labels array described above. For example, label_names[0] == "airplane", label_names[1] == "automobile", etc.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
## follow the instructions on the website
def unpickle(file):
    ## used to read binary files since our data files are in binary format
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %%
## loading data from binary data files
batch_1_dictionary = unpickle('cifar-10-data/data_batch_1')
batch_2_dictionary = unpickle('cifar-10-data/data_batch_2')

# %%
batch_1_dictionary.keys()
# Out:
# dict_keys([b'filenames', b'data', b'batch_label', b'labels'])

# %%
## get training, validation and testing sets
X_train_all = np.array(batch_1_dictionary[b'data']).reshape(10000,3,32,32)
y_train_all = np.array(batch_1_dictionary[b'labels'])
validation_count = 1000
train_count = X_train_all.shape[0]-1000
X_train = X_train_all[:train_count]
y_train = y_train_all[:train_count]
X_val = X_train_all[train_count:]
y_val = y_train_all[train_count:]
X_test = np.array(batch_2_dictionary[b'data']).reshape(10000,3,32,32)
y_test = np.array(batch_2_dictionary[b'labels'])

# %%
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((9000, 3, 32, 32),
#  (9000,),
#  (1000, 3, 32, 32),
#  (1000,),
#  (10000, 3, 32, 32),
#  (10000,))

# %% [markdown]
# ## 1.3 Preprocess Data
# Typically public datasets have some kind of data description or manual that we can use to gain basic understanding of the dataset. You should always try to look for such things and utilize them before you start processing the data. We now want to preprocess the data.
#
# We now want to do a data normalization. (Do you still remember why data normalization is important? Refer to Normalizing Input in first week of Improving Deep Neural Networks: Hyperparameter tuning, Regularization and Optimization)
# You can typically just do the minus by mean and divide by std normalization. But since we are dealing with image data, we can use another type of data normalization: simply divide by 255 to bring all features to the range (0,1).  (Think about why the number 255?) There are different ways to normalize data, feel free to try more options if you are interested.
#
# # TODO
# write your data normalization function here

# %%
# for RGB data we can simply divide by 255
X_train_normalized = X_train / 255
X_val_normalized = X_val / 255
X_test_normalized = X_test / 255

# %% [markdown]
# ## 1.4 Take a look at the data
# We can plot the image data to have a better understanding of it.

# %%
## class label related
CLASSES = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

def index_to_class_name(y):
    return CLASSES[y]
def class_name_to_index(class_name):
    return CLASSES.index(class_name)

# %%
import math
% matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
"""
Plotting utilities, if you want to know how these work exactly, check the reference
Or the documentations
reference: 
https://matplotlib.org/users/image_tutorial.html
https://stackoverflow.com/questions/46615554/how-to-display-multiple-images-in-one-figure-correctly/46616645
""" 

def show_single_image(data):
    # show a single image
    ## note that using matplotlib plotting function, we will have to reshape the data as (1,32,32,3)
    img = data.reshape(3,32,32).transpose(1,2,0)
    imgplot = plt.imshow(img)
def show_multiple_images(data, data_y, n_show=12, columns=4):
    ## given an array of data, show all of them as images
    fig=plt.figure(figsize=(8, 8))
    n = min(data.shape[0], n_show)
    rows = math.ceil(n/columns)
    for i in range(n):
        img = data[i].reshape(3,32,32).transpose(1,2,0)
        ax = fig.add_subplot(rows, columns, i+1) ## subplot index starts from 1 not 0
        class_name = index_to_class_name(data_y[i])
        ax.set_title(str(data_y[i])+": "+class_name)
        plt.imshow(img)
    plt.show()

# %%
show_multiple_images(X_train, y_train)

# %% [markdown]
# ## 2.1 Design Network Structure of a MLP Model
# Reference: https://pytorch.org/tutorials/beginner/blitz/neural_networks_tutorial.html
#
# When we use a multi-layer perceptron (a very basic neural net with fully connected layers), we will need to flatten the data so that the MLP can use it. Each data point in our training data is currently in the form of 1x32x32x3, we want to convert it into 1x3072, so that its shape makes sense to our MLP's input layer. Recall that in our MLP, the input size for the first layer is 3072. There are multiple ways of doing this, we can directly flatten all data points, or we can also do the flattening for each mini-batch.
#
# In terms of the loss function, since we are doing the task of multi-class classification, we will use the cross entropy loss.
#
# We will use nn.CrossEntropyLoss to compute this, refer to Pytorch doc for details. A short summary is "this criterion combines nn.LogSoftmax() and nn.NLLLoss() in one single class" That basically means we don't have to worry about softmax layer and the log part. Make sure you read the Pytorch doc to understand exactly how it works.
#
# # TODO
# write your network structure here
#
# 1. you should only use linear layers (nn.Linear), should use 2 or more linear layers
# 2. and you should use relu as activation
# 3. after the final layer we DON'T HAVE activation
# 4. you should not use softmax here because pytorch's BCE loss includes softmax
# 5. for hidden layer size, anything between 32-256 is OK

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import Tensor
import torch.optim as optim

class MLP(nn.Module):
    ## a very simple MLP model
    def __init__(self, input_dim, output_dim):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_dim,32)
        self.fc2 = nn.Linear(32,output_dim)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# utility for getting prediction accuracy
def get_correct_and_accuracy(y_pred, y):
    # y_pred is the nxC prediction scores
    # give the number of correct and the accuracy
    n = y.shape[0]
    # find the prediction class label
    _ ,pred_class = y_pred.max(dim=1)
    correct = (pred_class == y).sum().item()
    return correct ,correct/n

# %% [markdown]
# ## 2.2 Training the MLP model
# 1. We first initialize the neural network, and also the optimizer and the criterion (loss function)
# 2. We then convert data into correct tensor form (note for MLP we need to flatten the image data, from 3x32x32 to 3072)
# 3. We then start doing training iterations
#
# # TODO
# write code here
# 1. init your model
# 2. use Adam optimizer, with lr=1e-3
# 3. use cross entropy criterion
# 4. for X_train, X_val, cast to Tensor and then reshape them to flatten them (change shape to mx3072)
# 5. for y_train, y_val, cast to Tensor and then cast to type long
# 6. simply do 100 iterations

# %%
# init network
mlp = MLP(3072, 10)
print('model structure: ',mlp)
# init optimizer
optimizer = optim.Adam(mlp.parameters(),lr=1e-3)
# set loss function
criterion = nn.CrossEntropyLoss() 

# prepare for mini-batch stochastic gradient descent
n_iteration = 100
batch_size = 256
n_train_data = X_train_normalized.shape[0]
n_batch = int(np.ceil(n_train_data/batch_size))

# convert X_train and X_val to tensor and flatten them
X_train_tensor = Tensor(X_train_normalized).reshape(n_train_data,-1)
print(X_train_tensor.shape)
X_val_tensor = Tensor(X_val_normalized).reshape(1000,-1)
X_test_tensor = Tensor(X_test_normalized).reshape(10000,-1)

# convert training label to tensor and to type long
y_train_tensor = Tensor(y_train).long()
y_val_tensor = Tensor(y_val).long()
y_test_tensor = Tensor(y_test).long()
# Out:
# model structure:  MLP(
#   (fc1): Linear(in_features=3072, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=10, bias=True)
# )
# torch.Size([9000, 3072])

# %% [markdown]
# # TODO
# 1. Here you will have to write training code
# 2. As well as code to log the training process for later plotting
# 3. After each iteration through training data, you should use that print function to log you current training process

# %%
## start 
train_loss_list = np.zeros(n_iteration)
train_accu_list = np.zeros(n_iteration)
val_loss_list = np.zeros(n_iteration)
val_accu_list = np.zeros(n_iteration)
for i in range(n_iteration):
    # first get a minibatch of data
    
    for j in range(n_batch):
        batch_start_index = j*batch_size
        # get data batch from the normalized data
        X_batch = X_train_tensor[batch_start_index:batch_start_index+batch_size]
        # get ground truth label y
        y_batch = y_train_tensor[batch_start_index:batch_start_index+batch_size]
        #print(X_batch.shape)
        # compute prediction
        y_pred = mlp.forward(X_batch)
        loss = criterion(y_pred, y_batch)
        # do mini-batch gradient descent
        optimizer.zero_grad()
        # back propagation
        loss.backward()
        # optimize the gradient
        optimizer.step()
        ave_train_loss += loss
    ave_train_loss = ave_train_loss / n_batch 
    temp0,train_accu = get_correct_and_accuracy(y_pred,y_batch)
    y_val_pred = mlp.forward(X_val_tensor)
    val_loss = criterion(y_val_pred, y_val_tensor)
    temp1,val_accu = get_correct_and_accuracy(y_val_pred,y_val_tensor)
    print("Iter %d ,Train loss: %.3f, Train acc: %.3f, Val loss: %.3f, Val acc: %.3f" 
          %(i ,ave_train_loss, train_accu, val_loss, val_accu)) 
    
    ## add to the logs so that we can use them later for plotting
    
    train_loss_list[i] = ave_train_loss
    train_accu_list[i] = train_accu
    val_loss_list[i] = val_loss
    val_accu_list[i] = val_accu
# Out:
# Iter 0 ,Train loss: 0.367, Train acc: 0.925, Val loss: 2.675, Val acc: 0.339
# Iter 1 ,Train loss: 0.396, Train acc: 0.875, Val loss: 2.706, Val acc: 0.343
# Iter 2 ,Train loss: 0.386, Train acc: 0.900, Val loss: 2.697, Val acc: 0.350
# Iter 3 ,Train loss: 0.355, Train acc: 0.950, Val loss: 2.648, Val acc: 0.341
# Iter 4 ,Train loss: 0.331, Train acc: 0.950, Val loss: 2.651, Val acc: 0.340
# Iter 5 ,Train loss: 0.328, Train acc: 0.950, Val loss: 2.653, Val acc: 0.341
# Iter 6 ,Train loss: 0.306, Train acc: 0.975, Val loss: 2.644, Val acc: 0.336
# Iter 7 ,Train loss: 0.293, Train acc: 0.975, Val loss: 2.647, Val acc: 0.340
# Iter 8 ,Train loss: 0.289, Train acc: 0.950, Val loss: 2.624, Val acc: 0.343
# Iter 9 ,Train loss: 0.295, Train acc: 0.950, Val loss: 2.611, Val acc: 0.343
# Iter 10 ,Train loss: 0.279, Train acc: 0.975, Val loss: 2.597, Val acc: 0.344
# Iter 11 ,Train loss: 0.275, Train acc: 0.975, Val loss: 2.600, Val acc: 0.349
# Iter 12 ,Train loss: 0.261, Train acc: 0.975, Val loss: 2.589, Val acc: 0.344
# Iter 13 ,Train loss: 0.261, Train acc: 0.975, Val loss: 2.612, Val acc: 0.352
# Iter 14 ,Train loss: 0.283, Train acc: 0.925, Val loss: 2.642, Val acc: 0.344
# Iter 15 ,Train loss: 0.273, Train acc: 0.950, Val loss: 2.620, Val acc: 0.347
# Iter 16 ,Train loss: 0.269, Train acc: 0.975, Val loss: 2.621, Val acc: 0.347
# Iter 17 ,Train loss: 0.256, Train acc: 0.975, Val loss: 2.611, Val acc: 0.342
# Iter 18 ,Train loss: 0.258, Train acc: 0.975, Val loss: 2.600, Val acc: 0.342
# Iter 19 ,Train loss: 0.255, Train acc: 0.975, Val loss: 2.611, Val acc: 0.342
# Iter 20 ,Train loss: 0.254, Train acc: 0.975, Val loss: 2.593, Val acc: 0.339
# Iter 21 ,Train loss: 0.251, Train acc: 0.975, Val loss: 2.606, Val acc: 0.339
# Iter 22 ,Train loss: 0.254, Train acc: 0.975, Val loss: 2.593, Val acc: 0.342
# Iter 23 ,Train loss: 0.253, Train acc: 0.975, Val loss: 2.604, Val acc: 0.342
# Iter 24 ,Train loss: 0.257, Train acc: 0.975, Val loss: 2.603, Val acc: 0.343
# Iter 25 ,Train loss: 0.258, Train acc: 0.975, Val loss: 2.597, Val acc: 0.345
# Iter 26 ,Train loss: 0.265, Train acc: 0.975, Val loss: 2.588, Val acc: 0.344
# Iter 27 ,Train loss: 0.264, Train acc: 0.975, Val loss: 2.599, Val acc: 0.344
# Iter 28 ,Train loss: 0.263, Train acc: 0.975, Val loss: 2.615, Val acc: 0.338
# Iter 29 ,Train loss: 0.272, Train acc: 0.975, Val loss: 2.610, Val acc: 0.340
# Iter 30 ,Train loss: 0.268, Train acc: 0.975, Val loss: 2.593, Val acc: 0.339
# Iter 31 ,Train loss: 0.263, Train acc: 0.975, Val loss: 2.625, Val acc: 0.342
# Iter 32 ,Train loss: 0.271, Train acc: 0.975, Val loss: 2.630, Val acc: 0.336
# Iter 33 ,Train loss: 0.271, Train acc: 0.975, Val loss: 2.603, Val acc: 0.341
# Iter 34 ,Train loss: 0.264, Train acc: 0.975, Val loss: 2.634, Val acc: 0.341
# Iter 35 ,Train loss: 0.261, Train acc: 0.975, Val loss: 2.621, Val acc: 0.338
# Iter 36 ,Train loss: 0.256, Train acc: 0.975, Val loss: 2.644, Val acc: 0.341
# Iter 37 ,Train loss: 0.272, Train acc: 0.975, Val loss: 2.668, Val acc: 0.342
# Iter 38 ,Train loss: 0.268, Train acc: 0.975, Val loss: 2.648, Val acc: 0.343
# Iter 39 ,Train loss: 0.257, Train acc: 0.975, Val loss: 2.643, Val acc: 0.341
# Iter 40 ,Train loss: 0.248, Train acc: 0.975, Val loss: 2.648, Val acc: 0.336
# Iter 41 ,Train loss: 0.255, Train acc: 0.975, Val loss: 2.642, Val acc: 0.338
# Iter 42 ,Train loss: 0.256, Train acc: 0.975, Val loss: 2.663, Val acc: 0.341
# Iter 43 ,Train loss: 0.255, Train acc: 0.975, Val loss: 2.684, Val acc: 0.338
# Iter 44 ,Train loss: 0.260, Train acc: 0.975, Val loss: 2.664, Val acc: 0.344
# Iter 45 ,Train loss: 0.249, Train acc: 0.975, Val loss: 2.655, Val acc: 0.338
# Iter 46 ,Train loss: 0.243, Train acc: 0.975, Val loss: 2.670, Val acc: 0.342
# Iter 47 ,Train loss: 0.246, Train acc: 0.975, Val loss: 2.642, Val acc: 0.336
# Iter 48 ,Train loss: 0.251, Train acc: 0.975, Val loss: 2.657, Val acc: 0.341
# Iter 49 ,Train loss: 0.244, Train acc: 0.975, Val loss: 2.661, Val acc: 0.336
# Iter 50 ,Train loss: 0.247, Train acc: 0.975, Val loss: 2.652, Val acc: 0.338
# Iter 51 ,Train loss: 0.242, Train acc: 0.975, Val loss: 2.637, Val acc: 0.341
# Iter 52 ,Train loss: 0.240, Train acc: 0.975, Val loss: 2.629, Val acc: 0.340
# Iter 53 ,Train loss: 0.238, Train acc: 0.975, Val loss: 2.635, Val acc: 0.336
# Iter 54 ,Train loss: 0.239, Train acc: 0.975, Val loss: 2.649, Val acc: 0.329
# Iter 55 ,Train loss: 0.239, Train acc: 0.975, Val loss: 2.690, Val acc: 0.332
# Iter 56 ,Train loss: 0.233, Train acc: 0.975, Val loss: 2.670, Val acc: 0.337
# Iter 57 ,Train loss: 0.242, Train acc: 0.975, Val loss: 2.667, Val acc: 0.330
# Iter 58 ,Train loss: 0.234, Train acc: 0.975, Val loss: 2.640, Val acc: 0.334
# Iter 59 ,Train loss: 0.232, Train acc: 0.975, Val loss: 2.625, Val acc: 0.335
# Iter 60 ,Train loss: 0.234, Train acc: 0.975, Val loss: 2.649, Val acc: 0.339
# Iter 61 ,Train loss: 0.232, Train acc: 0.975, Val loss: 2.653, Val acc: 0.337
# Iter 62 ,Train loss: 0.246, Train acc: 0.975, Val loss: 2.661, Val acc: 0.337
# Iter 63 ,Train loss: 0.244, Train acc: 0.975, Val loss: 2.648, Val acc: 0.337
# Iter 64 ,Train loss: 0.245, Train acc: 0.975, Val loss: 2.676, Val acc: 0.334
# Iter 65 ,Train loss: 0.242, Train acc: 0.975, Val loss: 2.679, Val acc: 0.335
# Iter 66 ,Train loss: 0.257, Train acc: 0.975, Val loss: 2.736, Val acc: 0.337
# Iter 67 ,Train loss: 0.250, Train acc: 0.975, Val loss: 2.754, Val acc: 0.334
# Iter 68 ,Train loss: 0.250, Train acc: 0.975, Val loss: 2.806, Val acc: 0.329
# Iter 69 ,Train loss: 0.251, Train acc: 0.975, Val loss: 2.783, Val acc: 0.334
# Iter 70 ,Train loss: 0.253, Train acc: 0.975, Val loss: 2.771, Val acc: 0.338
# Iter 71 ,Train loss: 0.270, Train acc: 0.975, Val loss: 2.856, Val acc: 0.328
# Iter 72 ,Train loss: 0.248, Train acc: 0.975, Val loss: 2.818, Val acc: 0.327
# Iter 73 ,Train loss: 0.253, Train acc: 0.975, Val loss: 2.749, Val acc: 0.331
# Iter 74 ,Train loss: 0.251, Train acc: 0.975, Val loss: 2.636, Val acc: 0.337
# Iter 75 ,Train loss: 0.246, Train acc: 0.975, Val loss: 2.644, Val acc: 0.332
# Iter 76 ,Train loss: 0.250, Train acc: 0.975, Val loss: 2.649, Val acc: 0.333
# Iter 77 ,Train loss: 0.234, Train acc: 0.975, Val loss: 2.762, Val acc: 0.317
# Iter 78 ,Train loss: 0.226, Train acc: 0.975, Val loss: 2.748, Val acc: 0.326
# Iter 79 ,Train loss: 0.222, Train acc: 0.975, Val loss: 2.700, Val acc: 0.327
# Iter 80 ,Train loss: 0.239, Train acc: 0.975, Val loss: 2.692, Val acc: 0.329
# Iter 81 ,Train loss: 0.232, Train acc: 0.975, Val loss: 2.723, Val acc: 0.329
# Iter 82 ,Train loss: 0.228, Train acc: 0.975, Val loss: 2.713, Val acc: 0.334
# Iter 83 ,Train loss: 0.233, Train acc: 0.975, Val loss: 2.715, Val acc: 0.330
# Iter 84 ,Train loss: 0.224, Train acc: 0.975, Val loss: 2.697, Val acc: 0.333
# Iter 85 ,Train loss: 0.226, Train acc: 0.975, Val loss: 2.697, Val acc: 0.334
# Iter 86 ,Train loss: 0.232, Train acc: 0.975, Val loss: 2.719, Val acc: 0.332
# Iter 87 ,Train loss: 0.229, Train acc: 0.975, Val loss: 2.690, Val acc: 0.334
# Iter 88 ,Train loss: 0.222, Train acc: 0.975, Val loss: 2.716, Val acc: 0.334
# Iter 89 ,Train loss: 0.232, Train acc: 0.975, Val loss: 2.741, Val acc: 0.329
# Iter 90 ,Train loss: 0.221, Train acc: 0.975, Val loss: 2.716, Val acc: 0.324
# Iter 91 ,Train loss: 0.229, Train acc: 0.975, Val loss: 2.742, Val acc: 0.331
# Iter 92 ,Train loss: 0.221, Train acc: 0.975, Val loss: 2.750, Val acc: 0.331
# Iter 93 ,Train loss: 0.226, Train acc: 0.975, Val loss: 2.741, Val acc: 0.322
# Iter 94 ,Train loss: 0.221, Train acc: 0.975, Val loss: 2.750, Val acc: 0.331
# Iter 95 ,Train loss: 0.216, Train acc: 0.975, Val loss: 2.720, Val acc: 0.331
# Iter 96 ,Train loss: 0.222, Train acc: 0.975, Val loss: 2.755, Val acc: 0.330
# Iter 97 ,Train loss: 0.219, Train acc: 0.975, Val loss: 2.730, Val acc: 0.336
# Iter 98 ,Train loss: 0.217, Train acc: 0.975, Val loss: 2.751, Val acc: 0.337
# Iter 99 ,Train loss: 0.217, Train acc: 0.975, Val loss: 2.704, Val acc: 0.328

# %% [markdown]
# ## 2.3 Plotting training process
# We want to first plot training loss versus validation loss, then plot training accuracy, validation accuracy.
#
# # TODO
# run the plotting functions

# %%
## plot training loss versus validation loss
x_axis = np.arange(n_iteration)
plt.plot(x_axis, train_loss_list, label='train loss')
plt.plot(x_axis, val_loss_list, label='val loss')
plt.legend()
plt.show()

# %%
## plot training accuracy versus validation accuracy
plt.plot(x_axis, train_accu_list, label='train acc')
plt.plot(x_axis, val_accu_list, label='val acc')
plt.legend()
plt.show()

# %% [markdown]
# ## 2.4 Report testing performance
# We want run the trained model on test data to see how well it does
#
# # TODO
# write code here to report test accuracy on the 10000 test data

# %%
## test performance on the test set and report final performance
y_test_pred = mlp(X_test_tensor)
temp2,test_accu = get_correct_and_accuracy(y_test_pred,y_test_tensor)

print("Test accuracy: "+ str(test_accu) )
# Out:
# Test accuracy: 0.3613

# %% [markdown]
# ## 3.1 Now we design a convolutional network
# Check pytorch documentation for usage of each layer
#
# # TODO
# write network structure here
# you should do:
# 1. use at least 2 conv layer
# 2. at least 1 maxpool layer
# 3. at least 2 linear layer at the end

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.choices = nn.ModuleDict({
            'conv1': nn.Conv2d(3, 8, 3,padding = 1),
            'conv2': nn.Conv2d(8, 16, 3,padding = 1),
            'conv3': nn.Conv2d(16, 32, 3,padding = 1),
            'pool': nn.MaxPool2d(2),
            'fc1': nn.Linear(2048,32),
            'fc2': nn.Linear(32,10)
        })
        
    def forward(self, x):
        x = self.choices['conv1'](x)
        x = F.relu(x)
        x = self.choices['pool'](x)
        x = self.choices['conv2'](x)
        x = F.relu(x)
        x = self.choices['pool'](x)
        x = self.choices['conv3'](x)
        x = F.relu(x)
        l = x.shape[0]
        z = x.reshape(l,2048)
        x = self.choices['fc1'](z)
        x = F.relu(x)
        x = self.choices['fc2'](x)
        return x

# %% [markdown]
# ## 3.2 Training the Convolutional Net model
# 1. We first initialize the neural network, and also the optimizer and the criterion (loss function)
# 2. We then convert data into correct tensor form
# 3. We then start doing training iterations
#
# # TODO
# write code here
# 1. init your model
# 2. use Adam optimizer, with lr=1e-3
# 3. use cross entropy criterion
# 4. for X_train, X_val, cast to Tensor
# 5. for y_train, y_val, cast to Tensor and then cast to type long
# 6. simply do 40 iterations

# %%
# init network
conv_net = ConvNet()
print('model structure: ', conv_net)
# init optimizer
optimizer = optim.Adam(conv_net.parameters(),lr=1e-3)
# set loss function
criterion = nn.CrossEntropyLoss()

# prepare for mini-batch stochastic gradient descent
n_iteration = 50
batch_size = 256
n_data = X_train_normalized.shape[0]
n_batch = int(np.ceil(n_data/batch_size))

# convert X_train and X_val to tensor and flatten them
X_train_tensor = Tensor(X_train_normalized)
X_val_tensor = Tensor(X_val_normalized)
X_test_tensor = Tensor(X_test_normalized)

# convert training label to tensor and to type long
y_train_tensor = Tensor(y_train).long()
y_val_tensor = Tensor(y_val).long()
y_test_tensor = Tensor(y_test).long()

print('X train tensor shape:', X_train_tensor.shape)
# Out:
# model structure:  ConvNet(
#   (choices): ModuleDict(
#     (conv1): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fc1): Linear(in_features=2048, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=10, bias=True)
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
# )
# X train tensor shape: torch.Size([9000, 3, 32, 32])

# %% [markdown]
# # TODO
# 1. Here you will have to write training code
# 2. As well as code to log the training process for later plotting
# 3. After each iteration through training data, you should use that print function to log you current training process

# %%
## start 
train_loss_list = np.zeros(n_iteration)
train_accu_list = np.zeros(n_iteration)
val_loss_list = np.zeros(n_iteration)
val_accu_list = np.zeros(n_iteration)
for i in range(n_iteration):
    # first get a minibatch of data
    ave_train_loss = 0
    for j in range(n_batch):
        batch_start_index = j*batch_size
        # get data batch from the normalized data
        X_batch = X_train_tensor[batch_start_index:batch_start_index+batch_size]
        # get ground truth label y
        y_batch = y_train_tensor[batch_start_index:batch_start_index+batch_size]
        # compute the loss
        y_pred = conv_net.forward(X_batch)
        loss = criterion(y_pred,y_batch)
        # do mini-batch gradient descent
        optimizer.zero_grad()
        # back propagation
        loss.backward()
        # optimize the gradient
        optimizer.step()
        
        current_loss = conv_net.forward(X_batch)
        ave_train_loss += current_loss
        temp0,train_accu = get_correct_and_accuracy(y_pred,y_batch)
        y_val_pred = conv_net.forward(X_val_tensor)
        val_loss = criterion(y_val_pred, y_val_tensor)
        temp1,val_accu = get_correct_and_accuracy(y_val_pred,y_val_tensor)
        
    ave_train_loss = ave_train_loss / 256
    print("Iter %d ,Train loss: %.3f, Train acc: %.3f, Val loss: %.3f, Val acc: %.3f" 
          %(i ,ave_train_loss, train_accu, val_loss, val_accu)) 
    ## add to the logs so that we can use them later for plotting
    train_loss_list[i] = loss
    train_accu_list[i] = train_accu
    val_loss_list[i] = val_loss
    val_accu_list[i] = val_accu
# Out:
# Iter 0 ,Train loss: 2.246, Train acc: 0.150, Val loss: 2.169, Val acc: 0.199
# Iter 1 ,Train loss: 2.175, Train acc: 0.200, Val loss: 1.951, Val acc: 0.307
# Iter 2 ,Train loss: 2.026, Train acc: 0.250, Val loss: 1.791, Val acc: 0.352
# Iter 3 ,Train loss: 1.928, Train acc: 0.300, Val loss: 1.705, Val acc: 0.372
# Iter 4 ,Train loss: 1.878, Train acc: 0.275, Val loss: 1.658, Val acc: 0.382
# Iter 5 ,Train loss: 1.815, Train acc: 0.325, Val loss: 1.625, Val acc: 0.401
# Iter 6 ,Train loss: 1.761, Train acc: 0.375, Val loss: 1.594, Val acc: 0.424
# Iter 7 ,Train loss: 1.707, Train acc: 0.450, Val loss: 1.567, Val acc: 0.432
# Iter 8 ,Train loss: 1.657, Train acc: 0.475, Val loss: 1.545, Val acc: 0.453
# Iter 9 ,Train loss: 1.605, Train acc: 0.525, Val loss: 1.529, Val acc: 0.465
# Iter 10 ,Train loss: 1.549, Train acc: 0.550, Val loss: 1.515, Val acc: 0.469
# Iter 11 ,Train loss: 1.510, Train acc: 0.550, Val loss: 1.485, Val acc: 0.480
# Iter 12 ,Train loss: 1.474, Train acc: 0.550, Val loss: 1.465, Val acc: 0.489
# Iter 13 ,Train loss: 1.439, Train acc: 0.525, Val loss: 1.448, Val acc: 0.494
# Iter 14 ,Train loss: 1.409, Train acc: 0.525, Val loss: 1.433, Val acc: 0.506
# Iter 15 ,Train loss: 1.378, Train acc: 0.525, Val loss: 1.422, Val acc: 0.507
# Iter 16 ,Train loss: 1.351, Train acc: 0.525, Val loss: 1.414, Val acc: 0.498
# Iter 17 ,Train loss: 1.323, Train acc: 0.525, Val loss: 1.402, Val acc: 0.505
# Iter 18 ,Train loss: 1.293, Train acc: 0.600, Val loss: 1.396, Val acc: 0.509
# Iter 19 ,Train loss: 1.264, Train acc: 0.600, Val loss: 1.388, Val acc: 0.507
# Iter 20 ,Train loss: 1.235, Train acc: 0.675, Val loss: 1.385, Val acc: 0.504
# Iter 21 ,Train loss: 1.207, Train acc: 0.700, Val loss: 1.380, Val acc: 0.512
# Iter 22 ,Train loss: 1.180, Train acc: 0.700, Val loss: 1.379, Val acc: 0.507
# Iter 23 ,Train loss: 1.152, Train acc: 0.700, Val loss: 1.387, Val acc: 0.495
# Iter 24 ,Train loss: 1.126, Train acc: 0.700, Val loss: 1.387, Val acc: 0.497
# Iter 25 ,Train loss: 1.111, Train acc: 0.700, Val loss: 1.378, Val acc: 0.502
# Iter 26 ,Train loss: 1.118, Train acc: 0.700, Val loss: 1.349, Val acc: 0.517
# Iter 27 ,Train loss: 1.141, Train acc: 0.700, Val loss: 1.325, Val acc: 0.529
# Iter 28 ,Train loss: 1.146, Train acc: 0.750, Val loss: 1.326, Val acc: 0.519
# Iter 29 ,Train loss: 1.116, Train acc: 0.750, Val loss: 1.340, Val acc: 0.522
# Iter 30 ,Train loss: 1.080, Train acc: 0.750, Val loss: 1.335, Val acc: 0.519
# Iter 31 ,Train loss: 1.049, Train acc: 0.750, Val loss: 1.329, Val acc: 0.520
# Iter 32 ,Train loss: 1.017, Train acc: 0.750, Val loss: 1.325, Val acc: 0.526
# Iter 33 ,Train loss: 0.988, Train acc: 0.750, Val loss: 1.320, Val acc: 0.524
# Iter 34 ,Train loss: 0.954, Train acc: 0.750, Val loss: 1.318, Val acc: 0.530
# Iter 35 ,Train loss: 0.929, Train acc: 0.800, Val loss: 1.314, Val acc: 0.526
# Iter 36 ,Train loss: 0.905, Train acc: 0.800, Val loss: 1.313, Val acc: 0.521
# Iter 37 ,Train loss: 0.883, Train acc: 0.775, Val loss: 1.309, Val acc: 0.521
# Iter 38 ,Train loss: 0.857, Train acc: 0.775, Val loss: 1.305, Val acc: 0.521
# Iter 39 ,Train loss: 0.829, Train acc: 0.775, Val loss: 1.300, Val acc: 0.520
# Iter 40 ,Train loss: 0.806, Train acc: 0.775, Val loss: 1.295, Val acc: 0.522
# Iter 41 ,Train loss: 0.781, Train acc: 0.800, Val loss: 1.290, Val acc: 0.521
# Iter 42 ,Train loss: 0.760, Train acc: 0.800, Val loss: 1.285, Val acc: 0.525
# Iter 43 ,Train loss: 0.739, Train acc: 0.800, Val loss: 1.274, Val acc: 0.535
# Iter 44 ,Train loss: 0.712, Train acc: 0.800, Val loss: 1.271, Val acc: 0.542
# Iter 45 ,Train loss: 0.690, Train acc: 0.800, Val loss: 1.268, Val acc: 0.545
# Iter 46 ,Train loss: 0.669, Train acc: 0.800, Val loss: 1.268, Val acc: 0.538
# Iter 47 ,Train loss: 0.650, Train acc: 0.800, Val loss: 1.261, Val acc: 0.536
# Iter 48 ,Train loss: 0.629, Train acc: 0.800, Val loss: 1.262, Val acc: 0.535
# Iter 49 ,Train loss: 0.606, Train acc: 0.825, Val loss: 1.256, Val acc: 0.539

# %% [markdown]
# ## 3.3 Plotting training process
# We want to first plot training loss versus validation loss, then plot training accuracy, validation accuracy.
#
# # TODO
# run the code here for plotting

# %%
## plot training loss versus validation loss
x_axis = np.arange(n_iteration)
plt.plot(x_axis, train_loss_list, label='train loss')
plt.plot(x_axis, val_loss_list, label='val loss')
plt.legend()
plt.show()

# %%
## plot training accuracy versus validation accuracy
plt.plot(x_axis, train_accu_list, label='train acc')
plt.plot(x_axis, val_accu_list, label='val acc')
plt.legend()
plt.show()

# %% [markdown]
# ## 3.4 Report testing performance
# We want run the trained model on test data to see how well it does
#
# # TODO
# write code here to report test accuracy on the 10000 test data

# %%
## test performance on the test set and report final performance
y_test_pred = conv_net.forward(X_test_tensor)
temp2,test_accu = get_correct_and_accuracy(y_test_pred,y_test_tensor)
print("Test accuracy: ",test_accu)
# Out:
# Test accuracy:  0.543

# %% [markdown]
# ## Other things you can do to improve model performance:
# 1. Add in regularization, you can use l2, Dropout
# 2. Use a better data normalization method
# 3. Train on more data
# 4. Do data augmentation to get more data
# 5. Use a more powerful network structure
# 6. Do transfer learning
